# %% [markdown]
# <a href="https://colab.research.google.com/github/ddezouza/Data201_DanielaMelo/blob/main/Data201_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# # Title
# ## subtitle
#
# 1. first
# 2. second
# 3. third
#
# - [x] list1
# - [ ] list2

# %%
x = 1
y = 2

# %%
z=x+y

# %%
print(z)
# Out:
# 3
